# %%
pip install wooldridge

# %%
import pandas as pd
import wooldridge as wd
import numpy as np

# %%
actividad_2 = pd.read_excel("/content/activity_2_ml organizada.xlsm")

# %%
actividad_2
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 3      81    2       15000.0              17000.0       NaN      7  2744
# 4    1981    0       10000.0              13000.0  216000.0      7  2548
# ..    ...  ...           ...                  ...       ...    ...   ...
# 348  1981   51        2000.0               5000.0   50000.0      5  1140
# 349    81    1       22000.0              24000.0  162000.0      7  2656
# 350    78    3       12000.0              12000.0   64900.0      7  2856
# 351  1978   26       20000.0              22000.0   58000.0      6  1356
# 352  1978    0       24000.0              25000.0       NaN      7  2464
#
#          LAND  BATHS
# 0     45738.0      2
# 1     44867.0      3
# 2     18731.0      2
# ...

# %%
actividad_2["BATHS"].unique()
# Out:
# array([2, 3, 1, 4])

# %%
actividad_2["YEAR"].unique()
# Out:
# array([1978, 1981,   81,   78])

# %%
def funcion2(row):
  yea=row["YEAR"]
  if yea==1981:
   return np.random.choice([78,1978])
  return np.random.choice([81,1981])

actividad_2["year_problems"] = actividad_2.apply(funcion2,axis=1)

# %%
dictio_correct={81:1981,
            1981:1981,
            78:1978,
            1978:1978}

# %%
actividad_2["year_problems"]=actividad_2["year_problems"].map(dictio_correct)

# %%
actividad_2["year_problems"].unique()
# Out:
# array([1981, 1978])

# %%
actividad_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 353 non-null    int64
#  1   AGE                  353 non-null    int64
#  2   DISTANCE_BUS         353 non-null    float64
#  3   DISTANCE_INTERSTATE  353 non-null    float64
#  4   PRICE                283 non-null    float64
#  5   ROOMS                353 non-null    int64
#  6   AREA                 353 non-null    int64
#  7   LAND                 353 non-null    float64
#  8   BATHS                353 non-null    int64
#  9   year_problems        353 non-null    int64
# dtypes: float64(4), int64(6)
# memory usage: 27.7 KB

# %%
actividad_2.isna().sum()
# Out:
# YEAR                    0
# AGE                     0
# DISTANCE_BUS            0
# DISTANCE_INTERSTATE     0
# PRICE                  70
# ROOMS                   0
# AREA                    0
# LAND                    0
# BATHS                   0
# year_problems           0
# dtype: int64

# %% [markdown]
# # Visualización

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly

# %%
actividad_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 353 non-null    int64
#  1   AGE                  353 non-null    int64
#  2   DISTANCE_BUS         353 non-null    float64
#  3   DISTANCE_INTERSTATE  353 non-null    float64
#  4   PRICE                283 non-null    float64
#  5   ROOMS                353 non-null    int64
#  6   AREA                 353 non-null    int64
#  7   LAND                 353 non-null    float64
#  8   BATHS                353 non-null    int64
#  9   year_problems        353 non-null    int64
# dtypes: float64(4), int64(6)
# memory usage: 27.7 KB

# %%
actividad_2
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 3      81    2       15000.0              17000.0       NaN      7  2744
# 4    1981    0       10000.0              13000.0  216000.0      7  2548
# ..    ...  ...           ...                  ...       ...    ...   ...
# 348  1981   51        2000.0               5000.0   50000.0      5  1140
# 349    81    1       22000.0              24000.0  162000.0      7  2656
# 350    78    3       12000.0              12000.0   64900.0      7  2856
# 351  1978   26       20000.0              22000.0   58000.0      6  1356
# 352  1978    0       24000.0              25000.0       NaN      7  2464
#
#          LAND  BATHS  year_problems
# 0     45738.0      2           1981
# ...

# %% [markdown]
# # Garfico de barras

# %%
Year= actividad_2['year_problems'].value_counts() #construir una tabla de frecuencias
Year.index = ['1978', '1981']

# %%
Year
# Out:
# 1978    235
# 1981    118
# Name: year_problems, dtype: int64

# %%
plt.bar(Year.index, Year.values)
# Out:
# <BarContainer object of 2 artists>

# %%
sns.barplot(x=Year.index, y=Year.values, palette="viridis")
# Out:
# <ipython-input-141-b9adeb160469>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Year.index, y=Year.values, palette="viridis")
# <Axes: xlabel='None'>

# %% [markdown]
# #barras agrupadas

# %%
actividad_2['year_problems'] = pd.cut(actividad_2['BATHS'], 4, labels=['1','2','3','4'])

# %%
actividad_2['year_problems']
# Out:
# 0      2
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 348    1
# 349    3
# 350    2
# 351    2
# 352    3
# Name: year_problems, Length: 353, dtype: category
# Categories (4, object): ['1' < '2' < '3' < '4']

# %%
actividad_3 = actividad_2.replace({'BATHS':{1:'E.Bajo',2:'E.Medio',3:'E.Alto',4:'E.Superior'}})

# %%
actividad_3
# Out:
#      YEAR  AGE  DISTANCE_BUS  DISTANCE_INTERSTATE     PRICE  ROOMS  AREA  \
# 0    1978    1       30000.0              30000.0   75900.0      7  1836
# 1    1981    7       22000.0              22000.0  140000.0      6  1800
# 2    1981   31        3000.0               2000.0   68000.0      6  3304
# 3      81    2       15000.0              17000.0       NaN      7  2744
# 4    1981    0       10000.0              13000.0  216000.0      7  2548
# ..    ...  ...           ...                  ...       ...    ...   ...
# 348  1981   51        2000.0               5000.0   50000.0      5  1140
# 349    81    1       22000.0              24000.0  162000.0      7  2656
# 350    78    3       12000.0              12000.0   64900.0      7  2856
# 351  1978   26       20000.0              22000.0   58000.0      6  1356
# 352  1978    0       24000.0              25000.0       NaN      7  2464
#
#          LAND    BATHS year_problems
# 0     45738.0  E.Medio             2
# ...

# %%
actividad_3['BATHS'].value_counts()
# Out:
# E.Alto        174
# E.Medio       115
# E.Bajo         58
# E.Superior      6
# Name: BATHS, dtype: int64
